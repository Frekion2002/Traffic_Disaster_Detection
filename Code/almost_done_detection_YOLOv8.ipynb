# %%
from ultralytics import YOLO
import os
import shutil
from sklearn.model_selection import train_test_split
import torch
import ultralytics
import cv2
import matplotlib.pyplot as plt
from collections import defaultdict
from pathlib import Path
import glob
import optuna
from optuna.visualization import (
    plot_optimization_history,
    plot_param_importances,
    plot_parallel_coordinate,
    plot_slice
)
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image, ImageEnhance, ImageOps
from collections import Counter
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
print(f"PyTorch 버전: {torch.__version__}")
print(f"CUDA 사용 가능: {torch.cuda.is_available()}")
print(f"Ultralytics 버전: {ultralytics.__version__}")
print(f"CUDA 버전: {torch.version.cuda}")

model = YOLO('yolov8n.pt')
print(f"모델 작업 유형: {model.task}")
# Out:
# PyTorch 버전: 2.0.1+cu117
# CUDA 사용 가능: True
# Ultralytics 버전: 8.3.0
# CUDA 버전: 11.7
# 모델 작업 유형: detect

# %%
# 자동 정제 스크립트 (박스 우선 유지)

def clean_labels(label_dir):
    for filename in os.listdir(label_dir):
        filepath = os.path.join(label_dir, filename)
        with open(filepath, 'r') as f:
            lines = [l for l in f.readlines() if len(l.split()) == 5]
        
        with open(filepath, 'w') as f:
            f.writelines(lines)
        
clean_labels("C:/Users/user/Downloads/dataset/datasetHard/labels/train")
clean_labels("C:/Users/user/Downloads/dataset/datasetHard/labels/val")
clean_labels("C:/Users/user/Downloads/dataset/datasetHard/labels/test")

# %%
# 비어있는 파일이 있는 경우 성능 저하를 야기할 수 있으므로 비어 있는 label 파일과 이미지도 같이 삭제하는 파일

def clean_empty_labels(label_dir, image_dir=None, delete_images=False):
    label_dir = Path(label_dir)
    if image_dir:
        image_dir = Path(image_dir)

    removed_labels = 0
    removed_images = 0

    for label_file in label_dir.glob("*.txt"):
        if label_file.stat().st_size == 0:  # 파일이 비어있는지 확인
            # 라벨 파일 삭제
            label_file.unlink()
            removed_labels += 1

            if delete_images and image_dir:
                # 이미지 파일명 추정 (확장자 jpg, png 등)
                stem = label_file.stem
                for ext in ['.jpg', '.jpeg', '.png', '.bmp']:
                    img_file = image_dir / f"{stem}{ext}"
                    if img_file.exists():
                        img_file.unlink()
                        removed_images += 1
                        break

    print(f"삭제된 비어있는 라벨 파일: {removed_labels}개")
    if delete_images:
        print(f"함께 삭제된 이미지 파일: {removed_images}개")

        
# 라벨과 이미지 모두 삭제
clean_empty_labels(
    label_dir=r"C:\Users\user\Downloads\dataset\datasetHard\labels\train",
    image_dir=r"C:\Users\user\Downloads\dataset\datasetHard\images\train",
    delete_images=True
)

clean_empty_labels(
    label_dir=r"C:\Users\user\Downloads\dataset\datasetHard\labels\val",
    image_dir=r"C:\Users\user\Downloads\dataset\datasetHard\images\val",
    delete_images=True
)

clean_empty_labels(
    label_dir=r"C:\Users\user\Downloads\dataset\datasetHard\labels\test",
    image_dir=r"C:\Users\user\Downloads\dataset\datasetHard\images\test",
    delete_images=True
)
# Out:
# 삭제된 비어있는 라벨 파일: 0개
# 함께 삭제된 이미지 파일: 0개
# 삭제된 비어있는 라벨 파일: 0개
# 함께 삭제된 이미지 파일: 0개
# 삭제된 비어있는 라벨 파일: 0개
# 함께 삭제된 이미지 파일: 0개

# %%
# 비어있는 파일이 존재하는지 확인하는 코드

def check_labels(label_path):
    empty_found = False  # 비어있는 파일이 발견되었는지 여부
    for lbl_file in Path(label_path).glob("*.txt"):
        with open(lbl_file) as f:
            lines = f.readlines()
            if not lines:
                print(f"Empty file: {lbl_file}")
                empty_found = True
            for line in lines:
                parts = line.strip().split()
                if len(parts) != 5:
                    print(f"Invalid line in {lbl_file}: {line}")
    if not empty_found:
        print(f"[{label_path}] 비어있는 파일이 존재하지 않습니다.")

check_labels(r"C:\Users\user\Downloads\dataset\datasetHard\labels\train")
check_labels(r"C:\Users\user\Downloads\dataset\datasetHard\labels\val")
check_labels(r"C:\Users\user\Downloads\dataset\datasetHard\labels\test")
# Out:
# [C:\Users\user\Downloads\dataset\datasetHard\labels\train] 비어있는 파일이 존재하지 않습니다.
# [C:\Users\user\Downloads\dataset\datasetHard\labels\val] 비어있는 파일이 존재하지 않습니다.
# [C:\Users\user\Downloads\dataset\datasetHard\labels\test] 비어있는 파일이 존재하지 않습니다.

# %%
# YOLO 학습 과정에서 생성되는 캐시 파일 삭제하는 코드

cache_files = glob.glob(r"C:/Users/user/Downloads/dataset/datasetHard/labels/*.cache")
for f in cache_files:
    os.remove(f)
print(f"{len(cache_files)}개의 캐시 파일 삭제 완료")
# Out:
# 0개의 캐시 파일 삭제 완료

# %%
# 클래스별 인스턴스 수를 확인할 수 있는 코드

def count_instance_per_class(name, label_dir):
    class_counts = defaultdict(int)

    for label_file in Path(label_dir).glob("*.txt"):
        with open(label_file) as f:
            for line in f:
                if line.strip():
                    class_id = int(line.split()[0])
                    class_counts[class_id] += 1

    print("{} 클래스별 인스턴스 수:".format(name))
    class_counts = dict(sorted(class_counts.items()))
    for cls, cnt in class_counts.items():
        print(f"Class {cls}: {cnt}개")

count_instance_per_class("train", r"C:\Users\user\Downloads\dataset\datasetHard\labels\train")
count_instance_per_class("val", r"C:\Users\user\Downloads\dataset\datasetHard\labels\val")
count_instance_per_class("test", r"C:\Users\user\Downloads\dataset\datasetHard\labels\test")
# Out:
# train 클래스별 인스턴스 수:
# Class 0: 4256개
# Class 1: 2596개
# Class 2: 5858개
# Class 3: 786개
# val 클래스별 인스턴스 수:
# Class 0: 408개
# Class 1: 137개
# Class 2: 251개
# Class 3: 140개
# test 클래스별 인스턴스 수:
# Class 0: 192개
# Class 1: 284개
# Class 2: 135개
# Class 3: 176개

# %%
# 하이퍼파리미터 + 파라미터 튜닝 하는 부분

def objective(trial):
    try:
        # 하이퍼파라미터 서제스쳔
        lr0 = trial.suggest_float('lr0', 1e-4, 1e-1, log=True)
        batch = trial.suggest_categorical('batch', [8, 16, 32])
        mosaic = trial.suggest_float('mosaic', 0.0, 1.0)
        epochs = 50  # 고정값 사용

        # 모델 초기화 및 학습
        model = YOLO('yolov8n.pt')
        results = model.train(
            data=r"C:\Users\user\Downloads\dataset\datasetHard\data.yaml",
            epochs=epochs,
            lr0=lr0,
            batch=batch,
            mosaic=mosaic,
            imgsz=800,
            device='cuda',
            patience=20,
            verbose=False,  # 학습 로그 간소화
            amp=True,       # 메모리 절약
            plots=False     # Optuna 실행시 플롯 생성 방지
        )

        # mAP50 값 추출 (Ultralytics 버전별 호환성 처리)
        try:
            map50 = results.metrics['metrics/val_map_0.5']
        except AttributeError:
            map50 = results.metrics.map_50  # 8.3.0+ 버전

        return map50

    except Exception as e:
        print(f"Trial failed with error: {e}")
        return 0.0  # 실패시 0 반환

# Optuna 스터디 실행
study = optuna.create_study(
    direction='maximize',
    sampler=optuna.samplers.TPESampler(seed=42)  # 재현성 위해 시드 고정
)
study.optimize(objective, n_trials=10, show_progress_bar=True)

# 결과 출력
print("\n=== Best parameters ===")
print(study.best_params)
print(f"Best mAP50: {study.best_value:.3f}")

# 시각화
plot_optimization_history(study).show()
plot_param_importances(study).show()

# %%
# 최적화 하이퍼파라미터와 파러미터 간 상관관계, 파라미터별 성능 분포 시각화 파트

# 1. 최적화 히스토리(각 trial별 best value 변화)
fig1 = plot_optimization_history(study)
fig1.show()

# 2. 하이퍼파라미터 중요도(어떤 파라미터가 성능에 영향이 큰지)
fig2 = plot_param_importances(study)
fig2.show()

# 3. 파라미터 간 상관관계(Parallel Coordinate)
fig3 = plot_parallel_coordinate(study)
fig3.show()

# 4. 파라미터별 성능 분포(Slice Plot)
fig4 = plot_slice(study)
fig4.show()

# %%
# threshold를 변경해가면서 test

def test_model_with_thresholds(model,test_params):
    results_list = []
    print("\n📊 Threshold별 테스트 결과")
    print("Threshold |   mAP50   | Precision |  Recall")
    print("---------------------------------------------")

    test_params['conf'] = 0.01
    results = model.val(**test_params)
        # 결과 저장 및 출력
    map50 = results.box.map50
    precision = np.mean(results.box.p)
    recall = np.mean(results.box.r)
    print(f"  {map50:.4f}  |  {precision:.4f}  |  {recall:.4f}")
    results_list.append({
        'threshold': 0.01,
        'mAP50': map50,
        'precision': precision,
        'recall': recall
    })
    return results_list

# 1. 모델 로드
best_model_path = "runs/detect/train54/weights/best.pt"
print("Best model path:", best_model_path)
model = YOLO(best_model_path)

# 2. 테스트 파라미터 설정
test_params = {
    'data': r"C:\Users\user\Downloads\dataset\datasetHard\data.yaml",
    'split': 'test',
    'batch': 32,
    'name': 'disaster_detection_test',
    'plots': True,
    'save_json': False
}
 
results = test_model_with_thresholds(model, test_params)
# Out:
# Best model path: runs/detect/train54/weights/best.pt
#
# 📊 Threshold별 테스트 결과
# Threshold |   mAP50   | Precision |  Recall
# ---------------------------------------------
# Ultralytics 8.3.0  Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 186 layers, 2,685,148 parameters, 0 gradients, 6.8 GFLOPs
# val: Scanning C:\Users\user\Downloads\dataset\dataset\labels\test.cache... 561 images, 0 backgrounds, 0 corrupt: 100%|█
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:45
#                    all        561        687      0.883      0.827      0.884      0.668
#                  flood        135        207       0.86      0.816       0.85      0.712
#                   fire        106        142      0.924      0.965      0.976      0.697
#               accident        236        249      0.902      0.775      0.885      0.626
#               sinkhole         84         89      0.844      0.753      0.824      0.635
# Speed: 0.8ms preprocess, 2.4ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs\detect\disaster_detection_test31
#   0.8835  |  0.8825  |  0.8272

# %%
# 랜덤 5개 이미지에 대한 테스트 시각화

def visualize_extreme_diverse_predictions(model):
    test_images_dir = r"C:\Users\user\Downloads\dataset\datasetHard\images\test"
    all_images = os.listdir(test_images_dir)

    # 파일명에서 첫 단어로 그룹화
    image_groups = defaultdict(list)
    for img in all_images:
        if img:
            group_key = img.split('_')[0]  # 예: 'cat_01.jpg' → 'cat'
            image_groups[group_key].append(img)

    # 각 그룹에서 하나씩 뽑아 다양성 확보
    selected_images = [random.choice(group) for group in image_groups.values()]

    # 그룹이 5개 이상이면 랜덤하게 5개만 선택
    if len(selected_images) > 5:
        selected_images = random.sample(selected_images, 5)

    # 선택된 이미지에 대해 예측 및 결과 저장
    for img_name in selected_images:
        img_path = os.path.join(test_images_dir, img_name)
        results = model.predict(
            source=img_path,
            save=True,
            conf=0.01,  # 신뢰도 임계값
            save_dir='test_results'  # 예측 결과 저장 경로
        )
        print(f"{img_name} 예측 완료 → test_results 디렉토리 확인")

visualize_extreme_diverse_predictions(model)

# %%
# 실제 영상을 가지고 테스트하는 코드블럭

model = YOLO("runs/detect/train54/weights/best.pt")

# 클래스별 threshold 설정 (예시: 클래스 이름 기준)
class_thresholds = {
    'sinkhole': 0.01,    # sinkhole은 낮은 threshold로 더 많이 탐지
    'fire': 0.05,         # fire은 높은 threshold로 정확도 우선
    'accident': 0.7,
    'flood': 0.4
}

# 클래스 이름을 ID로 변환 (data.yaml의 names 순서와 일치해야 함)
class_names = model.names
class_id_to_threshold = {
    class_id: class_thresholds[class_name] 
    for class_id, class_name in class_names.items() 
    if class_name in class_thresholds
}

sink_video_path = "C:\\Users\\user\\Downloads\\Man on a scooter plunges into sinkhole.mp4"
acci_video_path = "C:\\Users\\user\\Downloads\\Shocking rear-end crash in Wordsley caught on CCTV.mp4"
fire_video_path = "C:\\Users\\user\\Downloads\\RAW Traffic camera shows vehicle fire on I-94E near Clearwater.mp4"
flood_video_path = "C:\\Users\\user\\Downloads\\flood_japan_cropped.mp4"
normal_video_path = "C:\\Users\\user\\Downloads\\gongneung2.mp4"
ezfire_video_path = "C:\\Users\\user\\Downloads\\easy_fire.mp4"

# %%
import cv2 as cv
from collections import Counter

def process_video(flood_video_path, model):
    cap = cv.VideoCapture(flood_video_path)
    fps = cap.get(cv.CAP_PROP_FPS) or 30

    # 창 크기 설정 (800x600)
    cv.namedWindow('Road Disaster Detection', cv.WINDOW_NORMAL)
    cv.resizeWindow('Road Disaster Detection', 800, 600)

    frame_buffer = []
    threshold_frames = 10
    consecutive_detection_required = 5
    detection_count = 0
    detected_classes = []
    event_start_frame = None

    paused = False  # 일시정지 상태 변수

    while True:
        if not paused:
            ret, frame = cap.read()
            if not ret:
                break
            frame_buffer.append(frame)

        if len(frame_buffer) == 15:
            current_frame = int(cap.get(cv.CAP_PROP_POS_FRAMES))
            batch_start_frame = current_frame - 15

            # 모델 예측
            results = model.predict(frame_buffer, imgsz=800, device='cuda', batch=15, conf=0.01)

            detected_frames = 0
            current_batch_classes = []

            for i, (frame, result) in enumerate(zip(frame_buffer, results)):
                vis_frame = frame.copy()
                if len(result.boxes) > 0:
                    for box in result.boxes:
                        cls = int(box.cls.item())
                        conf = box.conf.item()
                        if cls in class_id_to_threshold and conf >= class_id_to_threshold[cls]:
                            x1, y1, x2, y2 = map(int, box.xyxy[0])
                            cv.rectangle(vis_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                            label = f"{model.names[cls]} {conf:.2f}"
                            cv.putText(vis_frame, label, (x1, y1 - 10),
                                       cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                            current_batch_classes.append(cls)
                            detected_frames += 1
                frame_number = batch_start_frame + i
                cv.putText(vis_frame, f"Frame: {frame_number}", (10, 30),
                           cv.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

                vis_frame = cv.resize(vis_frame, (800, 600))
                cv.imshow('Road Disaster Detection', vis_frame)

                # 키 입력 처리
                key = cv.waitKey(10) & 0xFF
                if key == ord('q'):
                    cap.release()
                    cv.destroyAllWindows()
                    return
                elif key == 9 or key == 32:  # Tab(9) or Space(32)
                    paused = not paused
                    # 일시정지 상태에서 다음 키 입력까지 대기
                    while paused:
                        key2 = cv.waitKey(0) & 0xFF
                        if key2 == ord('q'):
                            cap.release()
                            cv.destroyAllWindows()
                            return
                        elif key2 == 9 or key2 == 32:
                            paused = False
                            break

            if detected_frames >= threshold_frames:
                detection_count += 1
                detected_classes.extend(current_batch_classes)
                if detection_count == 1:
                    event_start_frame = batch_start_frame
                print(f"Detection {detection_count} times in a row")
            else:
                detection_count = 0
                detected_classes = []
                event_start_frame = None

            if detection_count >= consecutive_detection_required:
                event_end_frame = current_frame - 1
                start_time_sec = event_start_frame / fps
                end_time_sec = event_end_frame / fps
                start_min = int(start_time_sec // 60)
                start_sec = int(start_time_sec % 60)
                end_min = int(end_time_sec // 60)
                end_sec = int(end_time_sec % 60)
                class_counts = Counter(detected_classes)
                print("\n🚨 Event detected!")
                print(f"⏰ Time: {start_min}:{start_sec:02d} ~ {end_min}:{end_sec:02d}")
                print("📦 Detected classes (with class-specific thresholds):")
                for cls, count in class_counts.items():
                    print(f"- {model.names[cls]} (threshold: {class_id_to_threshold[cls]}): {count} times")
                detection_count = 0
                detected_classes = []
                event_start_frame = None

            frame_buffer = []

    cap.release()
    cv.destroyAllWindows()
    print("Processing finished.")

process_video(acci_video_path, model)
# Out:
# 0: 480x800 2 accidents, 13.4ms
# 1: 480x800 2 accidents, 13.4ms
# 2: 480x800 2 accidents, 13.4ms
# 3: 480x800 2 accidents, 13.4ms
# 4: 480x800 4 accidents, 13.4ms
# 5: 480x800 4 accidents, 13.4ms
# 6: 480x800 4 accidents, 13.4ms
# 7: 480x800 3 accidents, 13.4ms
# 8: 480x800 2 accidents, 13.4ms
# 9: 480x800 3 accidents, 13.4ms
# 10: 480x800 3 accidents, 13.4ms
# 11: 480x800 5 accidents, 13.4ms
# 12: 480x800 5 accidents, 13.4ms
# 13: 480x800 5 accidents, 13.4ms
# 14: 480x800 4 accidents, 13.4ms
# Speed: 3.2ms preprocess, 13.4ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 1.1ms
# 1: 480x800 2 accidents, 1.1ms
# 2: 480x800 3 accidents, 1.1ms
# 3: 480x800 3 accidents, 1.1ms
# 4: 480x800 2 accidents, 1.1ms
# 5: 480x800 2 accidents, 1.1ms
# 6: 480x800 3 accidents, 1.1ms
# 7: 480x800 3 accidents, 1.1ms
# 8: 480x800 5 accidents, 1.1ms
# 9: 480x800 5 accidents, 1.1ms
# 10: 480x800 5 accidents, 1.1ms
# 11: 480x800 5 accidents, 1.1ms
# 12: 480x800 5 accidents, 1.1ms
# 13: 480x800 5 accidents, 1.1ms
# 14: 480x800 6 accidents, 1.1ms
# Speed: 1.9ms preprocess, 1.1ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 6 accidents, 1.0ms
# 1: 480x800 5 accidents, 1.0ms
# 2: 480x800 5 accidents, 1.0ms
# 3: 480x800 5 accidents, 1.0ms
# 4: 480x800 6 accidents, 1.0ms
# 5: 480x800 6 accidents, 1.0ms
# 6: 480x800 6 accidents, 1.0ms
# 7: 480x800 6 accidents, 1.0ms
# 8: 480x800 6 accidents, 1.0ms
# 9: 480x800 6 accidents, 1.0ms
# 10: 480x800 6 accidents, 1.0ms
# 11: 480x800 7 accidents, 1.0ms
# 12: 480x800 7 accidents, 1.0ms
# 13: 480x800 7 accidents, 1.0ms
# 14: 480x800 7 accidents, 1.0ms
# Speed: 0.9ms preprocess, 1.0ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 6 accidents, 1.0ms
# 1: 480x800 7 accidents, 1.0ms
# 2: 480x800 7 accidents, 1.0ms
# 3: 480x800 7 accidents, 1.0ms
# 4: 480x800 7 accidents, 1.0ms
# 5: 480x800 6 accidents, 1.0ms
# 6: 480x800 7 accidents, 1.0ms
# 7: 480x800 7 accidents, 1.0ms
# 8: 480x800 6 accidents, 1.0ms
# 9: 480x800 5 accidents, 1.0ms
# 10: 480x800 5 accidents, 1.0ms
# 11: 480x800 5 accidents, 1.0ms
# 12: 480x800 4 accidents, 1.0ms
# 13: 480x800 4 accidents, 1.0ms
# 14: 480x800 4 accidents, 1.0ms
# Speed: 2.1ms preprocess, 1.0ms inference, 0.2ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 1.0ms
# 1: 480x800 4 accidents, 1.0ms
# 2: 480x800 4 accidents, 1.0ms
# 3: 480x800 4 accidents, 1.0ms
# 4: 480x800 4 accidents, 1.0ms
# 5: 480x800 4 accidents, 1.0ms
# 6: 480x800 4 accidents, 1.0ms
# 7: 480x800 3 accidents, 1.0ms
# 8: 480x800 3 accidents, 1.0ms
# 9: 480x800 3 accidents, 1.0ms
# 10: 480x800 3 accidents, 1.0ms
# 11: 480x800 3 accidents, 1.0ms
# 12: 480x800 3 accidents, 1.0ms
# 13: 480x800 3 accidents, 1.0ms
# 14: 480x800 4 accidents, 1.0ms
# Speed: 1.1ms preprocess, 1.0ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 1.0ms
# 1: 480x800 3 accidents, 1.0ms
# 2: 480x800 3 accidents, 1.0ms
# 3: 480x800 3 accidents, 1.0ms
# 4: 480x800 4 accidents, 1.0ms
# 5: 480x800 3 accidents, 1.0ms
# 6: 480x800 3 accidents, 1.0ms
# 7: 480x800 3 accidents, 1.0ms
# 8: 480x800 3 accidents, 1.0ms
# 9: 480x800 4 accidents, 1.0ms
# 10: 480x800 4 accidents, 1.0ms
# 11: 480x800 3 accidents, 1.0ms
# 12: 480x800 5 accidents, 1.0ms
# 13: 480x800 5 accidents, 1.0ms
# 14: 480x800 4 accidents, 1.0ms
# Speed: 2.1ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 2.1ms
# 1: 480x800 4 accidents, 2.1ms
# 2: 480x800 3 accidents, 2.1ms
# 3: 480x800 3 accidents, 2.1ms
# 4: 480x800 4 accidents, 2.1ms
# 5: 480x800 4 accidents, 2.1ms
# 6: 480x800 4 accidents, 2.1ms
# 7: 480x800 2 accidents, 2.1ms
# 8: 480x800 2 accidents, 2.1ms
# 9: 480x800 3 accidents, 2.1ms
# 10: 480x800 4 accidents, 2.1ms
# 11: 480x800 2 accidents, 2.1ms
# 12: 480x800 2 accidents, 2.1ms
# 13: 480x800 2 accidents, 2.1ms
# 14: 480x800 1 accident, 2.1ms
# Speed: 1.1ms preprocess, 2.1ms inference, 1.3ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 2.1ms
# 1: 480x800 1 accident, 2.1ms
# 2: 480x800 1 accident, 2.1ms
# 3: 480x800 1 accident, 2.1ms
# 4: 480x800 4 accidents, 2.1ms
# 5: 480x800 4 accidents, 2.1ms
# 6: 480x800 5 accidents, 2.1ms
# 7: 480x800 4 accidents, 2.1ms
# 8: 480x800 4 accidents, 2.1ms
# 9: 480x800 4 accidents, 2.1ms
# 10: 480x800 4 accidents, 2.1ms
# 11: 480x800 4 accidents, 2.1ms
# 12: 480x800 3 accidents, 2.1ms
# 13: 480x800 2 accidents, 2.1ms
# 14: 480x800 2 accidents, 2.1ms
# Speed: 2.0ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 2.1ms
# 1: 480x800 1 accident, 2.1ms
# 2: 480x800 1 accident, 2.1ms
# 3: 480x800 1 accident, 2.1ms
# 4: 480x800 1 accident, 2.1ms
# 5: 480x800 1 accident, 2.1ms
# 6: 480x800 1 accident, 2.1ms
# 7: 480x800 1 accident, 2.1ms
# 8: 480x800 1 accident, 2.1ms
# 9: 480x800 3 accidents, 2.1ms
# 10: 480x800 3 accidents, 2.1ms
# 11: 480x800 3 accidents, 2.1ms
# 12: 480x800 3 accidents, 2.1ms
# 13: 480x800 3 accidents, 2.1ms
# 14: 480x800 3 accidents, 2.1ms
# Speed: 2.1ms preprocess, 2.1ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 2.1ms
# 1: 480x800 3 accidents, 2.1ms
# 2: 480x800 3 accidents, 2.1ms
# 3: 480x800 3 accidents, 2.1ms
# 4: 480x800 3 accidents, 2.1ms
# 5: 480x800 3 accidents, 2.1ms
# 6: 480x800 3 accidents, 2.1ms
# 7: 480x800 3 accidents, 2.1ms
# 8: 480x800 4 accidents, 2.1ms
# 9: 480x800 4 accidents, 2.1ms
# 10: 480x800 4 accidents, 2.1ms
# 11: 480x800 4 accidents, 2.1ms
# 12: 480x800 1 accident, 2.1ms
# 13: 480x800 1 accident, 2.1ms
# 14: 480x800 3 accidents, 2.1ms
# Speed: 1.9ms preprocess, 2.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 2.1ms
# 1: 480x800 2 accidents, 2.1ms
# 2: 480x800 1 accident, 2.1ms
# 3: 480x800 2 accidents, 2.1ms
# 4: 480x800 (no detections), 2.1ms
# 5: 480x800 (no detections), 2.1ms
# 6: 480x800 (no detections), 2.1ms
# 7: 480x800 1 accident, 2.1ms
# 8: 480x800 1 accident, 2.1ms
# 9: 480x800 1 accident, 2.1ms
# 10: 480x800 1 accident, 2.1ms
# 11: 480x800 (no detections), 2.1ms
# 12: 480x800 (no detections), 2.1ms
# 13: 480x800 (no detections), 2.1ms
# 14: 480x800 1 accident, 2.1ms
# Speed: 1.7ms preprocess, 2.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 3.2ms
# 1: 480x800 2 accidents, 3.2ms
# 2: 480x800 2 accidents, 3.2ms
# 3: 480x800 3 accidents, 3.2ms
# 4: 480x800 3 accidents, 3.2ms
# 5: 480x800 3 accidents, 3.2ms
# 6: 480x800 2 accidents, 3.2ms
# 7: 480x800 2 accidents, 3.2ms
# 8: 480x800 3 accidents, 3.2ms
# 9: 480x800 3 accidents, 3.2ms
# 10: 480x800 3 accidents, 3.2ms
# 11: 480x800 3 accidents, 3.2ms
# 12: 480x800 1 accident, 3.2ms
# 13: 480x800 1 accident, 3.2ms
# 14: 480x800 2 accidents, 3.2ms
# Speed: 0.9ms preprocess, 3.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 3.1ms
# 1: 480x800 1 accident, 3.1ms
# 2: 480x800 2 accidents, 3.1ms
# 3: 480x800 3 accidents, 3.1ms
# 4: 480x800 1 accident, 3.1ms
# 5: 480x800 1 accident, 3.1ms
# 6: 480x800 1 accident, 3.1ms
# 7: 480x800 2 accidents, 3.1ms
# 8: 480x800 2 accidents, 3.1ms
# 9: 480x800 2 accidents, 3.1ms
# 10: 480x800 2 accidents, 3.1ms
# 11: 480x800 3 accidents, 3.1ms
# 12: 480x800 3 accidents, 3.1ms
# 13: 480x800 3 accidents, 3.1ms
# 14: 480x800 4 accidents, 3.1ms
# Speed: 2.1ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 3.2ms
# 1: 480x800 3 accidents, 3.2ms
# 2: 480x800 3 accidents, 3.2ms
# 3: 480x800 3 accidents, 3.2ms
# 4: 480x800 4 accidents, 3.2ms
# 5: 480x800 4 accidents, 3.2ms
# 6: 480x800 6 accidents, 3.2ms
# 7: 480x800 5 accidents, 3.2ms
# 8: 480x800 5 accidents, 3.2ms
# 9: 480x800 5 accidents, 3.2ms
# 10: 480x800 5 accidents, 3.2ms
# 11: 480x800 5 accidents, 3.2ms
# 12: 480x800 3 accidents, 3.2ms
# 13: 480x800 3 accidents, 3.2ms
# 14: 480x800 3 accidents, 3.2ms
# Speed: 2.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 4.2ms
# 1: 480x800 3 accidents, 4.2ms
# 2: 480x800 1 accident, 4.2ms
# 3: 480x800 2 accidents, 4.2ms
# 4: 480x800 2 accidents, 4.2ms
# 5: 480x800 2 accidents, 4.2ms
# 6: 480x800 2 accidents, 4.2ms
# 7: 480x800 1 accident, 4.2ms
# 8: 480x800 1 accident, 4.2ms
# 9: 480x800 1 accident, 4.2ms
# 10: 480x800 1 accident, 4.2ms
# 11: 480x800 (no detections), 4.2ms
# 12: 480x800 (no detections), 4.2ms
# 13: 480x800 (no detections), 4.2ms
# 14: 480x800 3 accidents, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 3.2ms
# 1: 480x800 3 accidents, 3.2ms
# 2: 480x800 3 accidents, 3.2ms
# 3: 480x800 3 accidents, 3.2ms
# 4: 480x800 2 accidents, 3.2ms
# 5: 480x800 2 accidents, 3.2ms
# 6: 480x800 2 accidents, 3.2ms
# 7: 480x800 2 accidents, 3.2ms
# 8: 480x800 3 accidents, 3.2ms
# 9: 480x800 3 accidents, 3.2ms
# 10: 480x800 3 accidents, 3.2ms
# 11: 480x800 3 accidents, 3.2ms
# 12: 480x800 2 accidents, 3.2ms
# 13: 480x800 2 accidents, 3.2ms
# 14: 480x800 1 accident, 3.2ms
# Speed: 1.6ms preprocess, 3.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 4.2ms
# 1: 480x800 2 accidents, 4.2ms
# 2: 480x800 2 accidents, 4.2ms
# 3: 480x800 1 accident, 4.2ms
# 4: 480x800 3 accidents, 4.2ms
# 5: 480x800 3 accidents, 4.2ms
# 6: 480x800 2 accidents, 4.2ms
# 7: 480x800 2 accidents, 4.2ms
# 8: 480x800 2 accidents, 4.2ms
# 9: 480x800 3 accidents, 4.2ms
# 10: 480x800 3 accidents, 4.2ms
# 11: 480x800 3 accidents, 4.2ms
# 12: 480x800 3 accidents, 4.2ms
# 13: 480x800 3 accidents, 4.2ms
# 14: 480x800 3 accidents, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 4.2ms
# 1: 480x800 2 accidents, 4.2ms
# 2: 480x800 2 accidents, 4.2ms
# 3: 480x800 2 accidents, 4.2ms
# 4: 480x800 2 accidents, 4.2ms
# 5: 480x800 3 accidents, 4.2ms
# 6: 480x800 5 accidents, 4.2ms
# 7: 480x800 5 accidents, 4.2ms
# 8: 480x800 5 accidents, 4.2ms
# 9: 480x800 5 accidents, 4.2ms
# 10: 480x800 5 accidents, 4.2ms
# 11: 480x800 5 accidents, 4.2ms
# 12: 480x800 5 accidents, 4.2ms
# 13: 480x800 5 accidents, 4.2ms
# 14: 480x800 4 accidents, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 4.4ms
# 1: 480x800 5 accidents, 4.4ms
# 2: 480x800 4 accidents, 4.4ms
# 3: 480x800 4 accidents, 4.4ms
# 4: 480x800 4 accidents, 4.4ms
# 5: 480x800 4 accidents, 4.4ms
# 6: 480x800 4 accidents, 4.4ms
# 7: 480x800 4 accidents, 4.4ms
# 8: 480x800 4 accidents, 4.4ms
# 9: 480x800 4 accidents, 4.4ms
# 10: 480x800 4 accidents, 4.4ms
# 11: 480x800 4 accidents, 4.4ms
# 12: 480x800 4 accidents, 4.4ms
# 13: 480x800 4 accidents, 4.4ms
# 14: 480x800 4 accidents, 4.4ms
# Speed: 1.6ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 4.0ms
# 1: 480x800 4 accidents, 4.0ms
# 2: 480x800 4 accidents, 4.0ms
# 3: 480x800 4 accidents, 4.0ms
# 4: 480x800 4 accidents, 4.0ms
# 5: 480x800 4 accidents, 4.0ms
# 6: 480x800 3 accidents, 4.0ms
# 7: 480x800 3 accidents, 4.0ms
# 8: 480x800 4 accidents, 4.0ms
# 9: 480x800 4 accidents, 4.0ms
# 10: 480x800 4 accidents, 4.0ms
# 11: 480x800 4 accidents, 4.0ms
# 12: 480x800 4 accidents, 4.0ms
# 13: 480x800 4 accidents, 4.0ms
# 14: 480x800 5 accidents, 4.0ms
# Speed: 1.8ms preprocess, 4.0ms inference, 0.6ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 4.2ms
# 1: 480x800 (no detections), 4.2ms
# 2: 480x800 1 accident, 4.2ms
# 3: 480x800 1 accident, 4.2ms
# 4: 480x800 1 accident, 4.2ms
# 5: 480x800 1 accident, 4.2ms
# 6: 480x800 1 accident, 4.2ms
# 7: 480x800 1 accident, 4.2ms
# 8: 480x800 1 accident, 4.2ms
# 9: 480x800 1 accident, 4.2ms
# 10: 480x800 1 accident, 4.2ms
# 11: 480x800 2 accidents, 4.2ms
# 12: 480x800 2 accidents, 4.2ms
# 13: 480x800 2 accidents, 4.2ms
# 14: 480x800 2 accidents, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 3.1ms
# 1: 480x800 2 accidents, 3.1ms
# 2: 480x800 2 accidents, 3.1ms
# 3: 480x800 2 accidents, 3.1ms
# 4: 480x800 3 accidents, 3.1ms
# 5: 480x800 3 accidents, 3.1ms
# 6: 480x800 3 accidents, 3.1ms
# 7: 480x800 3 accidents, 3.1ms
# 8: 480x800 2 accidents, 3.1ms
# 9: 480x800 2 accidents, 3.1ms
# 10: 480x800 2 accidents, 3.1ms
# 11: 480x800 2 accidents, 3.1ms
# 12: 480x800 4 accidents, 3.1ms
# 13: 480x800 3 accidents, 3.1ms
# 14: 480x800 3 accidents, 3.1ms
# Speed: 2.1ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 11.3ms
# 1: 480x800 3 accidents, 11.3ms
# 2: 480x800 3 accidents, 11.3ms
# 3: 480x800 3 accidents, 11.3ms
# 4: 480x800 4 accidents, 11.3ms
# 5: 480x800 4 accidents, 11.3ms
# 6: 480x800 4 accidents, 11.3ms
# 7: 480x800 4 accidents, 11.3ms
# 8: 480x800 4 accidents, 11.3ms
# 9: 480x800 3 accidents, 11.3ms
# 10: 480x800 3 accidents, 11.3ms
# 11: 480x800 3 accidents, 11.3ms
# 12: 480x800 3 accidents, 11.3ms
# 13: 480x800 3 accidents, 11.3ms
# 14: 480x800 3 accidents, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 0.3ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 11.0ms
# 1: 480x800 3 accidents, 11.0ms
# 2: 480x800 3 accidents, 11.0ms
# 3: 480x800 3 accidents, 11.0ms
# 4: 480x800 3 accidents, 11.0ms
# 5: 480x800 3 accidents, 11.0ms
# 6: 480x800 3 accidents, 11.0ms
# 7: 480x800 3 accidents, 11.0ms
# 8: 480x800 3 accidents, 11.0ms
# 9: 480x800 3 accidents, 11.0ms
# 10: 480x800 3 accidents, 11.0ms
# 11: 480x800 3 accidents, 11.0ms
# 12: 480x800 3 accidents, 11.0ms
# 13: 480x800 3 accidents, 11.0ms
# 14: 480x800 3 accidents, 11.0ms
# Speed: 2.1ms preprocess, 11.0ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 10.2ms
# 1: 480x800 4 accidents, 10.2ms
# 2: 480x800 4 accidents, 10.2ms
# 3: 480x800 4 accidents, 10.2ms
# 4: 480x800 4 accidents, 10.2ms
# 5: 480x800 4 accidents, 10.2ms
# 6: 480x800 4 accidents, 10.2ms
# 7: 480x800 4 accidents, 10.2ms
# 8: 480x800 4 accidents, 10.2ms
# 9: 480x800 4 accidents, 10.2ms
# 10: 480x800 4 accidents, 10.2ms
# 11: 480x800 4 accidents, 10.2ms
# 12: 480x800 4 accidents, 10.2ms
# 13: 480x800 4 accidents, 10.2ms
# 14: 480x800 4 accidents, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 1.3ms
# 1: 480x800 4 accidents, 1.3ms
# 2: 480x800 4 accidents, 1.3ms
# 3: 480x800 4 accidents, 1.3ms
# 4: 480x800 4 accidents, 1.3ms
# 5: 480x800 4 accidents, 1.3ms
# 6: 480x800 4 accidents, 1.3ms
# 7: 480x800 4 accidents, 1.3ms
# 8: 480x800 4 accidents, 1.3ms
# 9: 480x800 4 accidents, 1.3ms
# 10: 480x800 4 accidents, 1.3ms
# 11: 480x800 4 accidents, 1.3ms
# 12: 480x800 4 accidents, 1.3ms
# 13: 480x800 4 accidents, 1.3ms
# 14: 480x800 4 accidents, 1.3ms
# Speed: 2.1ms preprocess, 1.3ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 1.9ms
# 1: 480x800 4 accidents, 1.9ms
# 2: 480x800 4 accidents, 1.9ms
# 3: 480x800 4 accidents, 1.9ms
# 4: 480x800 4 accidents, 1.9ms
# 5: 480x800 4 accidents, 1.9ms
# 6: 480x800 4 accidents, 1.9ms
# 7: 480x800 5 accidents, 1.9ms
# 8: 480x800 5 accidents, 1.9ms
# 9: 480x800 5 accidents, 1.9ms
# 10: 480x800 5 accidents, 1.9ms
# 11: 480x800 5 accidents, 1.9ms
# 12: 480x800 5 accidents, 1.9ms
# 13: 480x800 5 accidents, 1.9ms
# 14: 480x800 4 accidents, 1.9ms
# Speed: 0.9ms preprocess, 1.9ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 1.1ms
# 1: 480x800 4 accidents, 1.1ms
# 2: 480x800 4 accidents, 1.1ms
# 3: 480x800 4 accidents, 1.1ms
# 4: 480x800 6 accidents, 1.1ms
# 5: 480x800 6 accidents, 1.1ms
# 6: 480x800 5 accidents, 1.1ms
# 7: 480x800 5 accidents, 1.1ms
# 8: 480x800 4 accidents, 1.1ms
# 9: 480x800 4 accidents, 1.1ms
# 10: 480x800 4 accidents, 1.1ms
# 11: 480x800 4 accidents, 1.1ms
# 12: 480x800 4 accidents, 1.1ms
# 13: 480x800 4 accidents, 1.1ms
# 14: 480x800 4 accidents, 1.1ms
# Speed: 1.6ms preprocess, 1.1ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 5 accidents, 1.0ms
# 1: 480x800 5 accidents, 1.0ms
# 2: 480x800 5 accidents, 1.0ms
# 3: 480x800 5 accidents, 1.0ms
# 4: 480x800 5 accidents, 1.0ms
# 5: 480x800 5 accidents, 1.0ms
# 6: 480x800 5 accidents, 1.0ms
# 7: 480x800 5 accidents, 1.0ms
# 8: 480x800 5 accidents, 1.0ms
# 9: 480x800 5 accidents, 1.0ms
# 10: 480x800 5 accidents, 1.0ms
# 11: 480x800 5 accidents, 1.0ms
# 12: 480x800 5 accidents, 1.0ms
# 13: 480x800 5 accidents, 1.0ms
# 14: 480x800 6 accidents, 1.0ms
# Speed: 1.8ms preprocess, 1.0ms inference, 0.5ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 5 accidents, 2.1ms
# 1: 480x800 5 accidents, 2.1ms
# 2: 480x800 5 accidents, 2.1ms
# 3: 480x800 4 accidents, 2.1ms
# 4: 480x800 5 accidents, 2.1ms
# 5: 480x800 5 accidents, 2.1ms
# 6: 480x800 4 accidents, 2.1ms
# 7: 480x800 4 accidents, 2.1ms
# 8: 480x800 3 accidents, 2.1ms
# 9: 480x800 3 accidents, 2.1ms
# 10: 480x800 3 accidents, 2.1ms
# 11: 480x800 3 accidents, 2.1ms
# 12: 480x800 3 accidents, 2.1ms
# 13: 480x800 3 accidents, 2.1ms
# 14: 480x800 3 accidents, 2.1ms
# Speed: 0.7ms preprocess, 2.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 3.1ms
# 1: 480x800 3 accidents, 3.1ms
# 2: 480x800 3 accidents, 3.1ms
# 3: 480x800 3 accidents, 3.1ms
# 4: 480x800 3 accidents, 3.1ms
# 5: 480x800 3 accidents, 3.1ms
# 6: 480x800 3 accidents, 3.1ms
# 7: 480x800 3 accidents, 3.1ms
# 8: 480x800 3 accidents, 3.1ms
# 9: 480x800 4 accidents, 3.1ms
# 10: 480x800 3 accidents, 3.1ms
# 11: 480x800 4 accidents, 3.1ms
# 12: 480x800 4 accidents, 3.1ms
# 13: 480x800 4 accidents, 3.1ms
# 14: 480x800 3 accidents, 3.1ms
# Speed: 0.7ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 2.3ms
# 1: 480x800 3 accidents, 2.3ms
# 2: 480x800 3 accidents, 2.3ms
# 3: 480x800 4 accidents, 2.3ms
# 4: 480x800 3 accidents, 2.3ms
# 5: 480x800 3 accidents, 2.3ms
# 6: 480x800 4 accidents, 2.3ms
# 7: 480x800 4 accidents, 2.3ms
# 8: 480x800 4 accidents, 2.3ms
# 9: 480x800 4 accidents, 2.3ms
# 10: 480x800 4 accidents, 2.3ms
# 11: 480x800 4 accidents, 2.3ms
# 12: 480x800 5 accidents, 2.3ms
# 13: 480x800 5 accidents, 2.3ms
# 14: 480x800 4 accidents, 2.3ms
# Speed: 1.8ms preprocess, 2.3ms inference, 0.5ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 3.5ms
# 1: 480x800 3 accidents, 3.5ms
# 2: 480x800 4 accidents, 3.5ms
# 3: 480x800 4 accidents, 3.5ms
# 4: 480x800 4 accidents, 3.5ms
# 5: 480x800 4 accidents, 3.5ms
# 6: 480x800 4 accidents, 3.5ms
# 7: 480x800 4 accidents, 3.5ms
# 8: 480x800 4 accidents, 3.5ms
# 9: 480x800 4 accidents, 3.5ms
# 10: 480x800 4 accidents, 3.5ms
# 11: 480x800 4 accidents, 3.5ms
# 12: 480x800 4 accidents, 3.5ms
# 13: 480x800 4 accidents, 3.5ms
# 14: 480x800 5 accidents, 3.5ms
# Speed: 1.0ms preprocess, 3.5ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 5 accidents, 2.6ms
# 1: 480x800 5 accidents, 2.6ms
# 2: 480x800 5 accidents, 2.6ms
# 3: 480x800 5 accidents, 2.6ms
# 4: 480x800 5 accidents, 2.6ms
# 5: 480x800 5 accidents, 2.6ms
# 6: 480x800 4 accidents, 2.6ms
# 7: 480x800 4 accidents, 2.6ms
# 8: 480x800 4 accidents, 2.6ms
# 9: 480x800 4 accidents, 2.6ms
# 10: 480x800 4 accidents, 2.6ms
# 11: 480x800 4 accidents, 2.6ms
# 12: 480x800 3 accidents, 2.6ms
# 13: 480x800 3 accidents, 2.6ms
# 14: 480x800 3 accidents, 2.6ms
# Speed: 1.9ms preprocess, 2.6ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 2.3ms
# 1: 480x800 3 accidents, 2.3ms
# 2: 480x800 3 accidents, 2.3ms
# 3: 480x800 3 accidents, 2.3ms
# 4: 480x800 3 accidents, 2.3ms
# 5: 480x800 3 accidents, 2.3ms
# 6: 480x800 3 accidents, 2.3ms
# 7: 480x800 3 accidents, 2.3ms
# 8: 480x800 3 accidents, 2.3ms
# 9: 480x800 3 accidents, 2.3ms
# 10: 480x800 3 accidents, 2.3ms
# 11: 480x800 3 accidents, 2.3ms
# 12: 480x800 3 accidents, 2.3ms
# 13: 480x800 3 accidents, 2.3ms
# 14: 480x800 3 accidents, 2.3ms
# Speed: 2.0ms preprocess, 2.3ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 2.1ms
# 1: 480x800 4 accidents, 2.1ms
# 2: 480x800 4 accidents, 2.1ms
# 3: 480x800 4 accidents, 2.1ms
# 4: 480x800 4 accidents, 2.1ms
# 5: 480x800 5 accidents, 2.1ms
# 6: 480x800 5 accidents, 2.1ms
# 7: 480x800 5 accidents, 2.1ms
# 8: 480x800 5 accidents, 2.1ms
# 9: 480x800 5 accidents, 2.1ms
# 10: 480x800 5 accidents, 2.1ms
# 11: 480x800 5 accidents, 2.1ms
# 12: 480x800 5 accidents, 2.1ms
# 13: 480x800 5 accidents, 2.1ms
# 14: 480x800 5 accidents, 2.1ms
# Speed: 2.1ms preprocess, 2.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 5 accidents, 3.1ms
# 1: 480x800 6 accidents, 3.1ms
# 2: 480x800 5 accidents, 3.1ms
# 3: 480x800 5 accidents, 3.1ms
# 4: 480x800 5 accidents, 3.1ms
# 5: 480x800 5 accidents, 3.1ms
# 6: 480x800 5 accidents, 3.1ms
# 7: 480x800 4 accidents, 3.1ms
# 8: 480x800 4 accidents, 3.1ms
# 9: 480x800 4 accidents, 3.1ms
# 10: 480x800 4 accidents, 3.1ms
# 11: 480x800 4 accidents, 3.1ms
# 12: 480x800 5 accidents, 3.1ms
# 13: 480x800 4 accidents, 3.1ms
# 14: 480x800 4 accidents, 3.1ms
# Speed: 1.1ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 4.2ms
# 1: 480x800 3 accidents, 4.2ms
# 2: 480x800 3 accidents, 4.2ms
# 3: 480x800 3 accidents, 4.2ms
# 4: 480x800 5 accidents, 4.2ms
# 5: 480x800 5 accidents, 4.2ms
# 6: 480x800 5 accidents, 4.2ms
# 7: 480x800 5 accidents, 4.2ms
# 8: 480x800 4 accidents, 4.2ms
# 9: 480x800 4 accidents, 4.2ms
# 10: 480x800 4 accidents, 4.2ms
# 11: 480x800 4 accidents, 4.2ms
# 12: 480x800 4 accidents, 4.2ms
# 13: 480x800 4 accidents, 4.2ms
# 14: 480x800 4 accidents, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 3.6ms
# 1: 480x800 5 accidents, 3.6ms
# 2: 480x800 5 accidents, 3.6ms
# 3: 480x800 4 accidents, 3.6ms
# 4: 480x800 4 accidents, 3.6ms
# 5: 480x800 5 accidents, 3.6ms
# 6: 480x800 4 accidents, 3.6ms
# 7: 480x800 4 accidents, 3.6ms
# 8: 480x800 4 accidents, 3.6ms
# 9: 480x800 4 accidents, 3.6ms
# 10: 480x800 4 accidents, 3.6ms
# 11: 480x800 5 accidents, 3.6ms
# 12: 480x800 5 accidents, 3.6ms
# 13: 480x800 5 accidents, 3.6ms
# 14: 480x800 5 accidents, 3.6ms
# Speed: 1.7ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 5 accidents, 4.2ms
# 1: 480x800 5 accidents, 4.2ms
# 2: 480x800 5 accidents, 4.2ms
# 3: 480x800 5 accidents, 4.2ms
# 4: 480x800 5 accidents, 4.2ms
# 5: 480x800 5 accidents, 4.2ms
# 6: 480x800 5 accidents, 4.2ms
# 7: 480x800 5 accidents, 4.2ms
# 8: 480x800 5 accidents, 4.2ms
# 9: 480x800 5 accidents, 4.2ms
# 10: 480x800 5 accidents, 4.2ms
# 11: 480x800 5 accidents, 4.2ms
# 12: 480x800 5 accidents, 4.2ms
# 13: 480x800 5 accidents, 4.2ms
# 14: 480x800 5 accidents, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 4.2ms
# 1: 480x800 2 accidents, 4.2ms
# 2: 480x800 3 accidents, 4.2ms
# 3: 480x800 3 accidents, 4.2ms
# 4: 480x800 2 accidents, 4.2ms
# 5: 480x800 2 accidents, 4.2ms
# 6: 480x800 2 accidents, 4.2ms
# 7: 480x800 2 accidents, 4.2ms
# 8: 480x800 2 accidents, 4.2ms
# 9: 480x800 2 accidents, 4.2ms
# 10: 480x800 2 accidents, 4.2ms
# 11: 480x800 2 accidents, 4.2ms
# 12: 480x800 2 accidents, 4.2ms
# 13: 480x800 2 accidents, 4.2ms
# 14: 480x800 2 accidents, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 4.2ms
# 1: 480x800 2 accidents, 4.2ms
# 2: 480x800 2 accidents, 4.2ms
# 3: 480x800 2 accidents, 4.2ms
# 4: 480x800 2 accidents, 4.2ms
# 5: 480x800 2 accidents, 4.2ms
# 6: 480x800 2 accidents, 4.2ms
# 7: 480x800 2 accidents, 4.2ms
# 8: 480x800 2 accidents, 4.2ms
# 9: 480x800 2 accidents, 4.2ms
# 10: 480x800 2 accidents, 4.2ms
# 11: 480x800 2 accidents, 4.2ms
# 12: 480x800 2 accidents, 4.2ms
# 13: 480x800 2 accidents, 4.2ms
# 14: 480x800 2 accidents, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 4.0ms
# 1: 480x800 2 accidents, 4.0ms
# 2: 480x800 2 accidents, 4.0ms
# 3: 480x800 2 accidents, 4.0ms
# 4: 480x800 2 accidents, 4.0ms
# 5: 480x800 2 accidents, 4.0ms
# 6: 480x800 2 accidents, 4.0ms
# 7: 480x800 2 accidents, 4.0ms
# 8: 480x800 2 accidents, 4.0ms
# 9: 480x800 2 accidents, 4.0ms
# 10: 480x800 2 accidents, 4.0ms
# 11: 480x800 2 accidents, 4.0ms
# 12: 480x800 2 accidents, 4.0ms
# 13: 480x800 2 accidents, 4.0ms
# 14: 480x800 2 accidents, 4.0ms
# Speed: 1.6ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 3.2ms
# 1: 480x800 2 accidents, 3.2ms
# 2: 480x800 2 accidents, 3.2ms
# 3: 480x800 2 accidents, 3.2ms
# 4: 480x800 2 accidents, 3.2ms
# 5: 480x800 2 accidents, 3.2ms
# 6: 480x800 2 accidents, 3.2ms
# 7: 480x800 2 accidents, 3.2ms
# 8: 480x800 2 accidents, 3.2ms
# 9: 480x800 2 accidents, 3.2ms
# 10: 480x800 2 accidents, 3.2ms
# 11: 480x800 2 accidents, 3.2ms
# 12: 480x800 2 accidents, 3.2ms
# 13: 480x800 2 accidents, 3.2ms
# 14: 480x800 2 accidents, 3.2ms
# Speed: 1.5ms preprocess, 3.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 3.2ms
# 1: 480x800 4 accidents, 3.2ms
# 2: 480x800 4 accidents, 3.2ms
# 3: 480x800 3 accidents, 3.2ms
# 4: 480x800 4 accidents, 3.2ms
# 5: 480x800 4 accidents, 3.2ms
# 6: 480x800 4 accidents, 3.2ms
# 7: 480x800 4 accidents, 3.2ms
# 8: 480x800 4 accidents, 3.2ms
# 9: 480x800 4 accidents, 3.2ms
# 10: 480x800 4 accidents, 3.2ms
# 11: 480x800 4 accidents, 3.2ms
# 12: 480x800 4 accidents, 3.2ms
# 13: 480x800 4 accidents, 3.2ms
# 14: 480x800 4 accidents, 3.2ms
# Speed: 2.0ms preprocess, 3.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 3.2ms
# 1: 480x800 4 accidents, 3.2ms
# 2: 480x800 4 accidents, 3.2ms
# 3: 480x800 4 accidents, 3.2ms
# 4: 480x800 4 accidents, 3.2ms
# 5: 480x800 4 accidents, 3.2ms
# 6: 480x800 4 accidents, 3.2ms
# 7: 480x800 5 accidents, 3.2ms
# 8: 480x800 5 accidents, 3.2ms
# 9: 480x800 5 accidents, 3.2ms
# 10: 480x800 5 accidents, 3.2ms
# 11: 480x800 5 accidents, 3.2ms
# 12: 480x800 5 accidents, 3.2ms
# 13: 480x800 4 accidents, 3.2ms
# 14: 480x800 5 accidents, 3.2ms
# Speed: 2.1ms preprocess, 3.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 5 accidents, 4.3ms
# 1: 480x800 5 accidents, 4.3ms
# 2: 480x800 5 accidents, 4.3ms
# 3: 480x800 5 accidents, 4.3ms
# 4: 480x800 5 accidents, 4.3ms
# 5: 480x800 4 accidents, 4.3ms
# 6: 480x800 4 accidents, 4.3ms
# 7: 480x800 4 accidents, 4.3ms
# 8: 480x800 4 accidents, 4.3ms
# 9: 480x800 4 accidents, 4.3ms
# 10: 480x800 4 accidents, 4.3ms
# 11: 480x800 4 accidents, 4.3ms
# 12: 480x800 4 accidents, 4.3ms
# 13: 480x800 4 accidents, 4.3ms
# 14: 480x800 4 accidents, 4.3ms
# Speed: 1.1ms preprocess, 4.3ms inference, 1.1ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 4 accidents, 4.2ms
# 1: 480x800 4 accidents, 4.2ms
# 2: 480x800 3 accidents, 4.2ms
# 3: 480x800 2 accidents, 4.2ms
# 4: 480x800 3 accidents, 4.2ms
# 5: 480x800 4 accidents, 4.2ms
# 6: 480x800 3 accidents, 4.2ms
# 7: 480x800 3 accidents, 4.2ms
# 8: 480x800 3 accidents, 4.2ms
# 9: 480x800 3 accidents, 4.2ms
# 10: 480x800 3 accidents, 4.2ms
# 11: 480x800 4 accidents, 4.2ms
# 12: 480x800 4 accidents, 4.2ms
# 13: 480x800 4 accidents, 4.2ms
# 14: 480x800 5 accidents, 4.2ms
# Speed: 1.0ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 5 accidents, 4.9ms
# 1: 480x800 5 accidents, 4.9ms
# 2: 480x800 4 accidents, 4.9ms
# 3: 480x800 5 accidents, 4.9ms
# 4: 480x800 5 accidents, 4.9ms
# 5: 480x800 5 accidents, 4.9ms
# 6: 480x800 5 accidents, 4.9ms
# 7: 480x800 4 accidents, 4.9ms
# 8: 480x800 4 accidents, 4.9ms
# 9: 480x800 3 accidents, 4.9ms
# 10: 480x800 4 accidents, 4.9ms
# 11: 480x800 4 accidents, 4.9ms
# 12: 480x800 4 accidents, 4.9ms
# 13: 480x800 3 accidents, 4.9ms
# 14: 480x800 3 accidents, 4.9ms
# Speed: 0.7ms preprocess, 4.9ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 3.1ms
# 1: 480x800 3 accidents, 3.1ms
# 2: 480x800 3 accidents, 3.1ms
# 3: 480x800 2 accidents, 3.1ms
# 4: 480x800 3 accidents, 3.1ms
# 5: 480x800 3 accidents, 3.1ms
# 6: 480x800 3 accidents, 3.1ms
# 7: 480x800 2 accidents, 3.1ms
# 8: 480x800 3 accidents, 3.1ms
# 9: 480x800 3 accidents, 3.1ms
# 10: 480x800 2 accidents, 3.1ms
# 11: 480x800 2 accidents, 3.1ms
# 12: 480x800 3 accidents, 3.1ms
# 13: 480x800 2 accidents, 3.1ms
# 14: 480x800 3 accidents, 3.1ms
# Speed: 1.8ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 3.2ms
# 1: 480x800 2 accidents, 3.2ms
# 2: 480x800 3 accidents, 3.2ms
# 3: 480x800 3 accidents, 3.2ms
# 4: 480x800 4 accidents, 3.2ms
# 5: 480x800 3 accidents, 3.2ms
# 6: 480x800 3 accidents, 3.2ms
# 7: 480x800 3 accidents, 3.2ms
# 8: 480x800 4 accidents, 3.2ms
# 9: 480x800 4 accidents, 3.2ms
# 10: 480x800 4 accidents, 3.2ms
# 11: 480x800 4 accidents, 3.2ms
# 12: 480x800 3 accidents, 3.2ms
# 13: 480x800 3 accidents, 3.2ms
# 14: 480x800 2 accidents, 3.2ms
# Speed: 2.1ms preprocess, 3.2ms inference, 1.1ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 4.2ms
# 1: 480x800 2 accidents, 4.2ms
# 2: 480x800 2 accidents, 4.2ms
# 3: 480x800 2 accidents, 4.2ms
# 4: 480x800 2 accidents, 4.2ms
# 5: 480x800 2 accidents, 4.2ms
# 6: 480x800 2 accidents, 4.2ms
# 7: 480x800 2 accidents, 4.2ms
# 8: 480x800 2 accidents, 4.2ms
# 9: 480x800 2 accidents, 4.2ms
# 10: 480x800 3 accidents, 4.2ms
# 11: 480x800 3 accidents, 4.2ms
# 12: 480x800 5 accidents, 4.2ms
# 13: 480x800 5 accidents, 4.2ms
# 14: 480x800 2 accidents, 4.2ms
# Speed: 0.7ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 3.9ms
# 1: 480x800 2 accidents, 3.9ms
# 2: 480x800 2 accidents, 3.9ms
# 3: 480x800 2 accidents, 3.9ms
# 4: 480x800 3 accidents, 3.9ms
# 5: 480x800 3 accidents, 3.9ms
# 6: 480x800 5 accidents, 3.9ms
# 7: 480x800 6 accidents, 3.9ms
# 8: 480x800 5 accidents, 3.9ms
# 9: 480x800 6 accidents, 3.9ms
# 10: 480x800 6 accidents, 3.9ms
# 11: 480x800 5 accidents, 3.9ms
# 12: 480x800 5 accidents, 3.9ms
# 13: 480x800 6 accidents, 3.9ms
# 14: 480x800 6 accidents, 3.9ms
# Speed: 2.1ms preprocess, 3.9ms inference, 0.5ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 6 accidents, 4.0ms
# 1: 480x800 5 accidents, 4.0ms
# 2: 480x800 5 accidents, 4.0ms
# 3: 480x800 5 accidents, 4.0ms
# 4: 480x800 4 accidents, 4.0ms
# 5: 480x800 4 accidents, 4.0ms
# 6: 480x800 4 accidents, 4.0ms
# 7: 480x800 4 accidents, 4.0ms
# 8: 480x800 5 accidents, 4.0ms
# 9: 480x800 5 accidents, 4.0ms
# 10: 480x800 5 accidents, 4.0ms
# 11: 480x800 5 accidents, 4.0ms
# 12: 480x800 4 accidents, 4.0ms
# 13: 480x800 2 accidents, 4.0ms
# 14: 480x800 1 accident, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.5ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 4.1ms
# 1: 480x800 1 accident, 4.1ms
# 2: 480x800 4 accidents, 4.1ms
# 3: 480x800 3 accidents, 4.1ms
# 4: 480x800 2 accidents, 4.1ms
# 5: 480x800 2 accidents, 4.1ms
# 6: 480x800 2 accidents, 4.1ms
# 7: 480x800 2 accidents, 4.1ms
# 8: 480x800 2 accidents, 4.1ms
# 9: 480x800 1 accident, 4.1ms
# 10: 480x800 1 accident, 4.1ms
# 11: 480x800 1 accident, 4.1ms
# 12: 480x800 1 accident, 4.1ms
# 13: 480x800 1 accident, 4.1ms
# 14: 480x800 1 accident, 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 0.5ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 10.6ms
# 1: 480x800 1 accident, 10.6ms
# 2: 480x800 1 accident, 10.6ms
# 3: 480x800 1 accident, 10.6ms
# 4: 480x800 2 accidents, 10.6ms
# 5: 480x800 2 accidents, 10.6ms
# 6: 480x800 2 accidents, 10.6ms
# 7: 480x800 2 accidents, 10.6ms
# 8: 480x800 2 accidents, 10.6ms
# 9: 480x800 2 accidents, 10.6ms
# 10: 480x800 2 accidents, 10.6ms
# 11: 480x800 2 accidents, 10.6ms
# 12: 480x800 3 accidents, 10.6ms
# 13: 480x800 3 accidents, 10.6ms
# 14: 480x800 3 accidents, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
# Detection 1 times in a row
#
# 0: 480x800 1 accident, 10.6ms
# 1: 480x800 1 accident, 10.6ms
# 2: 480x800 1 accident, 10.6ms
# 3: 480x800 1 accident, 10.6ms
# 4: 480x800 2 accidents, 10.6ms
# 5: 480x800 2 accidents, 10.6ms
# 6: 480x800 2 accidents, 10.6ms
# 7: 480x800 1 accident, 10.6ms
# 8: 480x800 1 accident, 10.6ms
# 9: 480x800 2 accidents, 10.6ms
# 10: 480x800 2 accidents, 10.6ms
# 11: 480x800 2 accidents, 10.6ms
# 12: 480x800 2 accidents, 10.6ms
# 13: 480x800 2 accidents, 10.6ms
# 14: 480x800 2 accidents, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 1.0ms
# 1: 480x800 2 accidents, 1.0ms
# 2: 480x800 2 accidents, 1.0ms
# 3: 480x800 2 accidents, 1.0ms
# 4: 480x800 1 accident, 1.0ms
# 5: 480x800 1 accident, 1.0ms
# 6: 480x800 (no detections), 1.0ms
# 7: 480x800 (no detections), 1.0ms
# 8: 480x800 (no detections), 1.0ms
# 9: 480x800 (no detections), 1.0ms
# 10: 480x800 (no detections), 1.0ms
# 11: 480x800 (no detections), 1.0ms
# 12: 480x800 1 accident, 1.0ms
# 13: 480x800 1 accident, 1.0ms
# 14: 480x800 2 accidents, 1.0ms
# Speed: 1.8ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 2.4ms
# 1: 480x800 1 accident, 2.4ms
# 2: 480x800 2 accidents, 2.4ms
# 3: 480x800 2 accidents, 2.4ms
# 4: 480x800 1 accident, 2.4ms
# 5: 480x800 1 accident, 2.4ms
# 6: 480x800 1 accident, 2.4ms
# 7: 480x800 1 accident, 2.4ms
# 8: 480x800 1 accident, 2.4ms
# 9: 480x800 3 accidents, 2.4ms
# 10: 480x800 3 accidents, 2.4ms
# 11: 480x800 2 accidents, 2.4ms
# 12: 480x800 2 accidents, 2.4ms
# 13: 480x800 2 accidents, 2.4ms
# 14: 480x800 (no detections), 2.4ms
# Speed: 1.8ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 (no detections), 10.6ms
# 1: 480x800 1 accident, 10.6ms
# 2: 480x800 1 accident, 10.6ms
# 3: 480x800 1 accident, 10.6ms
# 4: 480x800 (no detections), 10.6ms
# 5: 480x800 (no detections), 10.6ms
# 6: 480x800 (no detections), 10.6ms
# 7: 480x800 (no detections), 10.6ms
# 8: 480x800 (no detections), 10.6ms
# 9: 480x800 (no detections), 10.6ms
# 10: 480x800 (no detections), 10.6ms
# 11: 480x800 (no detections), 10.6ms
# 12: 480x800 (no detections), 10.6ms
# 13: 480x800 (no detections), 10.6ms
# 14: 480x800 1 accident, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 1.1ms
# 1: 480x800 2 accidents, 1.1ms
# 2: 480x800 3 accidents, 1.1ms
# 3: 480x800 2 accidents, 1.1ms
# 4: 480x800 2 accidents, 1.1ms
# 5: 480x800 2 accidents, 1.1ms
# 6: 480x800 2 accidents, 1.1ms
# 7: 480x800 2 accidents, 1.1ms
# 8: 480x800 2 accidents, 1.1ms
# 9: 480x800 2 accidents, 1.1ms
# 10: 480x800 2 accidents, 1.1ms
# 11: 480x800 2 accidents, 1.1ms
# 12: 480x800 2 accidents, 1.1ms
# 13: 480x800 2 accidents, 1.1ms
# 14: 480x800 3 accidents, 1.1ms
# Speed: 1.8ms preprocess, 1.1ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 1.0ms
# 1: 480x800 3 accidents, 1.0ms
# 2: 480x800 3 accidents, 1.0ms
# 3: 480x800 3 accidents, 1.0ms
# 4: 480x800 4 accidents, 1.0ms
# 5: 480x800 3 accidents, 1.0ms
# 6: 480x800 2 accidents, 1.0ms
# 7: 480x800 2 accidents, 1.0ms
# 8: 480x800 1 accident, 1.0ms
# 9: 480x800 2 accidents, 1.0ms
# 10: 480x800 1 accident, 1.0ms
# 11: 480x800 1 accident, 1.0ms
# 12: 480x800 2 accidents, 1.0ms
# 13: 480x800 2 accidents, 1.0ms
# 14: 480x800 1 accident, 1.0ms
# Speed: 0.7ms preprocess, 1.0ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 3.2ms
# 1: 480x800 1 accident, 3.2ms
# 2: 480x800 (no detections), 3.2ms
# 3: 480x800 (no detections), 3.2ms
# 4: 480x800 (no detections), 3.2ms
# 5: 480x800 (no detections), 3.2ms
# 6: 480x800 (no detections), 3.2ms
# 7: 480x800 (no detections), 3.2ms
# 8: 480x800 (no detections), 3.2ms
# 9: 480x800 1 accident, 3.2ms
# 10: 480x800 1 accident, 3.2ms
# 11: 480x800 1 accident, 3.2ms
# 12: 480x800 2 accidents, 3.2ms
# 13: 480x800 2 accidents, 3.2ms
# 14: 480x800 1 accident, 3.2ms
# Speed: 2.1ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 4.2ms
# 1: 480x800 1 accident, 4.2ms
# 2: 480x800 1 accident, 4.2ms
# 3: 480x800 1 accident, 4.2ms
# 4: 480x800 3 accidents, 4.2ms
# 5: 480x800 3 accidents, 4.2ms
# 6: 480x800 2 accidents, 4.2ms
# 7: 480x800 2 accidents, 4.2ms
# 8: 480x800 2 accidents, 4.2ms
# 9: 480x800 1 accident, 4.2ms
# 10: 480x800 1 accident, 4.2ms
# 11: 480x800 1 accident, 4.2ms
# 12: 480x800 1 accident, 4.2ms
# 13: 480x800 1 accident, 4.2ms
# 14: 480x800 1 accident, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 4.2ms
# 1: 480x800 1 accident, 4.2ms
# 2: 480x800 3 accidents, 4.2ms
# 3: 480x800 3 accidents, 4.2ms
# 4: 480x800 3 accidents, 4.2ms
# 5: 480x800 3 accidents, 4.2ms
# 6: 480x800 2 accidents, 4.2ms
# 7: 480x800 2 accidents, 4.2ms
# 8: 480x800 2 accidents, 4.2ms
# 9: 480x800 2 accidents, 4.2ms
# 10: 480x800 2 accidents, 4.2ms
# 11: 480x800 2 accidents, 4.2ms
# 12: 480x800 2 accidents, 4.2ms
# 13: 480x800 2 accidents, 4.2ms
# 14: 480x800 1 accident, 4.2ms
# Speed: 1.9ms preprocess, 4.2ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 11.6ms
# 1: 480x800 1 accident, 11.6ms
# 2: 480x800 1 accident, 11.6ms
# 3: 480x800 1 accident, 11.6ms
# 4: 480x800 (no detections), 11.6ms
# 5: 480x800 (no detections), 11.6ms
# 6: 480x800 (no detections), 11.6ms
# 7: 480x800 (no detections), 11.6ms
# 8: 480x800 (no detections), 11.6ms
# 9: 480x800 (no detections), 11.6ms
# 10: 480x800 (no detections), 11.6ms
# 11: 480x800 (no detections), 11.6ms
# 12: 480x800 (no detections), 11.6ms
# 13: 480x800 (no detections), 11.6ms
# 14: 480x800 1 accident, 11.6ms
# Speed: 2.1ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 (no detections), 18.0ms
# 1: 480x800 (no detections), 18.0ms
# 2: 480x800 1 accident, 18.0ms
# 3: 480x800 1 accident, 18.0ms
# 4: 480x800 1 accident, 18.0ms
# 5: 480x800 2 accidents, 18.0ms
# 6: 480x800 1 accident, 18.0ms
# 7: 480x800 1 accident, 18.0ms
# 8: 480x800 1 accident, 18.0ms
# 9: 480x800 1 accident, 18.0ms
# 10: 480x800 1 accident, 18.0ms
# 11: 480x800 1 accident, 18.0ms
# 12: 480x800 1 accident, 18.0ms
# 13: 480x800 1 accident, 18.0ms
# 14: 480x800 1 accident, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 (no detections), 1.0ms
# 1: 480x800 1 accident, 1.0ms
# 2: 480x800 1 accident, 1.0ms
# 3: 480x800 1 accident, 1.0ms
# 4: 480x800 (no detections), 1.0ms
# 5: 480x800 (no detections), 1.0ms
# 6: 480x800 (no detections), 1.0ms
# 7: 480x800 (no detections), 1.0ms
# 8: 480x800 (no detections), 1.0ms
# 9: 480x800 (no detections), 1.0ms
# 10: 480x800 (no detections), 1.0ms
# 11: 480x800 (no detections), 1.0ms
# 12: 480x800 (no detections), 1.0ms
# 13: 480x800 (no detections), 1.0ms
# 14: 480x800 2 accidents, 1.0ms
# Speed: 1.0ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 3 accidents, 1.9ms
# 1: 480x800 3 accidents, 1.9ms
# 2: 480x800 4 accidents, 1.9ms
# 3: 480x800 3 accidents, 1.9ms
# 4: 480x800 3 accidents, 1.9ms
# 5: 480x800 3 accidents, 1.9ms
# 6: 480x800 3 accidents, 1.9ms
# 7: 480x800 2 accidents, 1.9ms
# 8: 480x800 2 accidents, 1.9ms
# 9: 480x800 2 accidents, 1.9ms
# 10: 480x800 2 accidents, 1.9ms
# 11: 480x800 2 accidents, 1.9ms
# 12: 480x800 2 accidents, 1.9ms
# 13: 480x800 2 accidents, 1.9ms
# 14: 480x800 1 accident, 1.9ms
# Speed: 1.3ms preprocess, 1.9ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 4.5ms
# 1: 480x800 2 accidents, 4.5ms
# 2: 480x800 2 accidents, 4.5ms
# 3: 480x800 2 accidents, 4.5ms
# 4: 480x800 2 accidents, 4.5ms
# 5: 480x800 2 accidents, 4.5ms
# 6: 480x800 1 accident, 4.5ms
# 7: 480x800 1 accident, 4.5ms
# 8: 480x800 2 accidents, 4.5ms
# 9: 480x800 2 accidents, 4.5ms
# 10: 480x800 2 accidents, 4.5ms
# 11: 480x800 1 accident, 4.5ms
# 12: 480x800 2 accidents, 4.5ms
# 13: 480x800 2 accidents, 4.5ms
# 14: 480x800 1 accident, 4.5ms
# Speed: 0.7ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 1 accident, 3.1ms
# 1: 480x800 1 accident, 3.1ms
# 2: 480x800 (no detections), 3.1ms
# 3: 480x800 (no detections), 3.1ms
# 4: 480x800 1 accident, 3.1ms
# 5: 480x800 1 accident, 3.1ms
# 6: 480x800 1 accident, 3.1ms
# 7: 480x800 1 accident, 3.1ms
# 8: 480x800 1 accident, 3.1ms
# 9: 480x800 4 accidents, 3.1ms
# 10: 480x800 4 accidents, 3.1ms
# 11: 480x800 1 accident, 3.1ms
# 12: 480x800 1 accident, 3.1ms
# 13: 480x800 1 accident, 3.1ms
# 14: 480x800 2 accidents, 3.1ms
# Speed: 2.1ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (15, 3, 480, 800)
#
# 0: 480x800 2 accidents, 3.2ms
# 1: 480x800 1 accident, 3.2ms
# 2: 480x800 1 accident, 3.2ms
# 3: 480x800 1 accident, 3.2ms
# 4: 480x800 1 accident, 3.2ms
# 5: 480x800 1 accident, 3.2ms
# 6: 480x800 1 accident, 3.2ms
# 7: 480x800 1 accident, 3.2ms
# 8: 480x800 2 accidents, 3.2ms
# 9: 480x800 2 accidents, 3.2ms
# 10: 480x800 2 accidents, 3.2ms
# 11: 480x800 2 accidents, 3.2ms
# 12: 480x800 2 accidents, 3.2ms
# 13: 480x800 3 accidents, 3.2ms
# 14: 480x800 2 accidents, 3.2ms
# Speed: 1.6ms preprocess, 3.2ms inference, 1.1ms postprocess per image at shape (15, 3, 480, 800)
